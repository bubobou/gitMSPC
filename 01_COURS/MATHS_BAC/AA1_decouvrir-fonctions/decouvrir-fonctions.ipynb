# %% [markdown]
# ### Situation : programmation en python
#
# Parmi les programmes définis ci-dessous, lesquels correspondent au programme de calcul initial ?

# %%
# programme 1
def programme_de_calcul1(nombre):
    resultat = 3*nombre
    resultat = resultat + 1
    resultat = resultat / 2
    return resultat

# %%
# programme 2
def programme_de_calcul2(x):
    resultat = 3*x
    resultat = resultat + 1
    resultat = resultat / 2
    return resultat

# %%
# programme 3
def programme_de_calcul3(nombre):
    nombre = 3*nombre
    nombre = nombre + 1
    nombre = nombre / 2
    return nombre

# %%
# programme 4
def fonction(antecedent):
    image = 3*antecedent
    image = image + 1
    image = image / 2
    return image

# %% [markdown]
# Utilisation des fonctions:

# %%
# programme 1
programme_de_calcul1(-2)
programme_de_calcul1(0)
programme_de_calcul1(3)
programme_de_calcul1(10)
